# %% [markdown]
# <a href="https://colab.research.google.com/github/ris2002/RNN_Scratch_Using_numpy_Pytorch/blob/main/RNN_Transformer_From_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *RNN* Architecture- Numpy

# %% [markdown]
# Forward Pass

# %% [markdown]
# First Data Preparation, Tokenisation and converting to Embeddings

# %%
import kagglehub
import os
# Download latest version
path = kagglehub.dataset_download("swimmingwhale/dinosaur-island")
file_path = os.path.join(path, "dinos.txt")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'dinosaur-island' dataset.
# Path to dataset files: /kaggle/input/dinosaur-island

# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
df=pd.read_csv(file_path,header=None,names=['name'])# in read_csv func names param helps to mannually provide a col name

# %%
df['name'][12]
# Out:
# 'Acristavus'

# %%
df['name'].shape
# Out:
# (1536,)

# %%
char_list=[]
for name in df['name']:
  clean_name=name.lower()
  d_array=np.array(list(clean_name))#dummy array
  char_list.append(d_array)

# %%
char_list
# Out:
# [array(['a', 'a', 'c', 'h', 'e', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'a', 'r', 'd', 'o', 'n', 'y', 'x'], dtype='<U1'),
#  array(['a', 'b', 'd', 'a', 'l', 'l', 'a', 'h', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['a', 'b', 'e', 'l', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'b', 'r', 'i', 'c', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'b', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'b', 'y', 'd', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'c', 'a', 'n', 't', 'h', 'o', 'p', 'h', 'o', 'l', 'i', 's'],
#        dtype='<U1'),
#  array(['a', 'c', 'h', 'e', 'l', 'o', 'u', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'c', 'h', 'e', 'r', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['a', 'c', 'h', 'i', 'l', 'l', 'e', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'c', 'h', 'i', 'l', 'l', 'o', 'b', 'a', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['a', 'c', 'r', 'i', 's', 't', 'a', 'v', 'u', 's'], dtype='<U1'),
#  array(['a', 'c', 'r', 'o', 'c', 'a', 'n', 't', 'h', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'c', 'r', 'o', 't', 'h', 'o', 'l', 'u', 's'], dtype='<U1'),
#  array(['a', 'c', 't', 'i', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'd', 'a', 'm', 'a', 'n', 't', 'i', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['a', 'd', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'd', 'e', 'l', 'o', 'l', 'o', 'p', 'h', 'u', 's'], dtype='<U1'),
#  array(['a', 'd', 'e', 'o', 'p', 'a', 'p', 'p', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['a', 'e', 'g', 'y', 'p', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'e', 'o', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'e', 'p', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'e', 'p', 'y', 'o', 'r', 'n', 'i', 't', 'h', 'o', 'm', 'i',
#         'm', 'u', 's'], dtype='<U1'),
#  array(['a', 'e', 'r', 'o', 's', 't', 'e', 'o', 'n'], dtype='<U1'),
#  array(['a', 'e', 't', 'o', 'n', 'y', 'x', 'a', 'f', 'r', 'o', 'm', 'i',
#         'm', 'u', 's'], dtype='<U1'),
#  array(['a', 'f', 'r', 'o', 'v', 'e', 'n', 'a', 't', 'o', 'r'], dtype='<U1'),
#  array(['a', 'g', 'a', 't', 'h', 'a', 'u', 'm', 'a', 's'], dtype='<U1'),
#  array(['a', 'g', 'g', 'i', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'g', 'i', 'l', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'g', 'n', 'o', 's', 'p', 'h', 'i', 't', 'y', 's'], dtype='<U1'),
#  array(['a', 'g', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'g', 'u', 'j', 'a', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['a', 'g', 'u', 's', 't', 'i', 'n', 'i', 'a'], dtype='<U1'),
#  array(['a', 'h', 's', 'h', 'i', 's', 'l', 'e', 'p', 'e', 'l', 't', 'a'],
#        dtype='<U1'),
#  array(['a', 'i', 'r', 'a', 'k', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['a', 'j', 'a', 'n', 'c', 'i', 'n', 'g', 'e', 'n', 'i', 'a'],
#        dtype='<U1'),
#  array(['a', 'j', 'k', 'a', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['a', 'l', 'a', 'm', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'l', 'a', 's', 'k', 'a', 'c', 'e', 'p', 'h', 'a', 'l', 'e'],
#        dtype='<U1'),
#  array(['a', 'l', 'b', 'a', 'l', 'o', 'p', 'h', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['a', 'l', 'b', 'e', 'r', 't', 'a', 'c', 'e', 'r', 'a', 't', 'o',
#         'p', 's'], dtype='<U1'),
#  array(['a', 'l', 'b', 'e', 'r', 't', 'a', 'd', 'r', 'o', 'm', 'e', 'u',
#         's'], dtype='<U1'),
#  array(['a', 'l', 'b', 'e', 'r', 't', 'a', 'v', 'e', 'n', 'a', 't', 'o',
#         'r'], dtype='<U1'),
#  array(['a', 'l', 'b', 'e', 'r', 't', 'o', 'n', 'y', 'k', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'l', 'b', 'e', 'r', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'l', 'b', 'i', 'n', 'y', 'k', 'u', 's'], dtype='<U1'),
#  array(['a', 'l', 'b', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'l', 'c', 'o', 'v', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'l', 'e', 'c', 't', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'l', 'e', 't', 'o', 'p', 'e', 'l', 't', 'a'], dtype='<U1'),
#  array(['a', 'l', 'g', 'o', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'l', 'i', 'o', 'r', 'a', 'm', 'u', 's'], dtype='<U1'),
#  array(['a', 'l', 'i', 'w', 'a', 'l', 'i', 'a'], dtype='<U1'),
#  array(['a', 'l', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'l', 'm', 'a', 's'], dtype='<U1'),
#  array(['a', 'l', 'n', 'a', 's', 'h', 'e', 't', 'r', 'i'], dtype='<U1'),
#  array(['a', 'l', 'o', 'c', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['a', 'l', 't', 'i', 'r', 'h', 'i', 'n', 'u', 's'], dtype='<U1'),
#  array(['a', 'l', 't', 'i', 's', 'p', 'i', 'n', 'a', 'x'], dtype='<U1'),
#  array(['a', 'l', 'v', 'a', 'r', 'e', 'z', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'l', 'w', 'a', 'l', 'k', 'e', 'r', 'i', 'a'], dtype='<U1'),
#  array(['a', 'l', 'x', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'm', 'a', 'r', 'g', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'm', 'a', 'r', 'g', 'a', 's', 't', 'e', 'g', 'o', 's'],
#        dtype='<U1'),
#  array(['a', 'm', 'a', 'r', 'g', 'a', 't', 'i', 't', 'a', 'n', 'i', 's'],
#        dtype='<U1'),
#  array(['a', 'm', 'a', 'z', 'o', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'm', 'm', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'm', 'p', 'e', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'm', 'p', 'h', 'i', 'c', 'o', 'e', 'l', 'i', 'a', 's'],
#        dtype='<U1'),
#  array(['a', 'm', 'p', 'h', 'i', 'c', 'o', 'e', 'l', 'i', 'c', 'a', 'u',
#         'd', 'i', 'a'], dtype='<U1'),
#  array(['a', 'm', 'p', 'h', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'm', 't', 'o', 'c', 'e', 'p', 'h', 'a', 'l', 'e'], dtype='<U1'),
#  array(['a', 'm', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'm', 'u', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'm', 'y', 'g', 'd', 'a', 'l', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['a', 'n', 'a', 'b', 'i', 's', 'e', 't', 'i', 'a'], dtype='<U1'),
#  array(['a', 'n', 'a', 's', 'a', 'z', 'i', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'n', 'a', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'n', 'a', 't', 'o', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['a', 'n', 'c', 'h', 'i', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['a', 'n', 'c', 'h', 'i', 'o', 'r', 'n', 'i', 's'], dtype='<U1'),
#  array(['a', 'n', 'c', 'h', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'n', 'd', 'e', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'n', 'd', 'h', 'r', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'n', 'g', 'a', 't', 'u', 'r', 'a', 'm', 'a'], dtype='<U1'),
#  array(['a', 'n', 'g', 'l', 'o', 'p', 'o', 's', 'e', 'i', 'd', 'o', 'n'],
#        dtype='<U1'),
#  array(['a', 'n', 'g', 'o', 'l', 'a', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['a', 'n', 'g', 'u', 'l', 'o', 'm', 'a', 's', 't', 'a', 'c', 'a',
#         't', 'o', 'r'], dtype='<U1'),
#  array(['a', 'n', 'i', 'k', 's', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'n', 'i', 'm', 'a', 'n', 't', 'a', 'r', 'x'], dtype='<U1'),
#  array(['a', 'n', 'k', 'i', 's', 't', 'r', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['a', 'n', 'k', 'y', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'n', 'o', 'd', 'o', 'n', 't', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['a', 'n', 'o', 'p', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'n', 's', 'e', 'r', 'i', 'm', 'i', 'm', 'u', 's'], dtype='<U1'),
#  array(['a', 'n', 't', 'a', 'r', 'c', 't', 'o', 'p', 'e', 'l', 't', 'a'],
#        dtype='<U1'),
#  array(['a', 'n', 't', 'a', 'r', 'c', 't', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['a', 'n', 't', 'e', 't', 'o', 'n', 'i', 't', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'n', 't', 'h', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['a', 'n', 't', 'r', 'o', 'd', 'e', 'm', 'u', 's'], dtype='<U1'),
#  array(['a', 'n', 'z', 'u'], dtype='<U1'),
#  array(['a', 'o', 'n', 'i', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['a', 'o', 'r', 'u', 'n'], dtype='<U1'),
#  array(['a', 'p', 'a', 't', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['a', 'p', 'a', 't', 'o', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['a', 'p', 'a', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'p', 'p', 'a', 'l', 'a', 'c', 'h', 'i', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'q', 'u', 'i', 'l', 'o', 'p', 's'], dtype='<U1'),
#  array(['a', 'r', 'a', 'g', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'a', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'a', 'u', 'c', 'a', 'n', 'o', 'r', 'a', 'p', 't', 'o',
#         'r'], dtype='<U1'),
#  array(['a', 'r', 'c', 'h', 'a', 'e', 'o', 'c', 'e', 'r', 'a', 't', 'o',
#         'p', 's'], dtype='<U1'),
#  array(['a', 'r', 'c', 'h', 'a', 'e', 'o', 'd', 'o', 'n', 't', 'o', 's',
#         'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'c', 'h', 'a', 'e', 'o', 'p', 't', 'e', 'r', 'y', 'x'],
#        dtype='<U1'),
#  array(['a', 'r', 'c', 'h', 'a', 'e', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['a', 'r', 'c', 'h', 'a', 'e', 'o', 'r', 'n', 'i', 's'], dtype='<U1'),
#  array(['a', 'r', 'c', 'h', 'a', 'e', 'o', 'r', 'n', 'i', 't', 'h', 'o',
#         'i', 'd', 'e', 's'], dtype='<U1'),
#  array(['a', 'r', 'c', 'h', 'a', 'e', 'o', 'r', 'n', 'i', 't', 'h', 'o',
#         'm', 'i', 'm', 'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'c', 'o', 'v', 'e', 'n', 'a', 't', 'o', 'r'], dtype='<U1'),
#  array(['a', 'r', 'c', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'c', 'u', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'e', 'n', 'y', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'g', 'e', 'n', 't', 'i', 'n', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'g', 'y', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'r', 'i', 's', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'r', 'i', 's', 't', 'o', 's', 'u', 'c', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'r', 'i', 'z', 'o', 'n', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'r', 'k', 'a', 'n', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'r', 'k', 'h', 'a', 'r', 'a', 'v', 'i', 'a'], dtype='<U1'),
#  array(['a', 'r', 'r', 'h', 'i', 'n', 'o', 'c', 'e', 'r', 'a', 't', 'o',
#         'p', 's'], dtype='<U1'),
#  array(['a', 'r', 's', 't', 'a', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 's', 'i', 'a', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['a', 's', 'i', 'a', 'm', 'e', 'r', 'i', 'c', 'a', 'n', 'a'],
#        dtype='<U1'),
#  array(['a', 's', 'i', 'a', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 's', 't', 'r', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['a', 's', 't', 'r', 'o', 'd', 'o', 'n', 'i', 'u', 's'], dtype='<U1'),
#  array(['a', 's', 't', 'r', 'o', 'd', 'o', 'n', 't', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['a', 's', 't', 'r', 'o', 'p', 'h', 'o', 'c', 'a', 'u', 'd', 'i',
#         'a'], dtype='<U1'),
#  array(['a', 's', 'y', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 't', 'a', 'c', 'a', 'm', 'a', 't', 'i', 't', 'a', 'n'],
#        dtype='<U1'),
#  array(['a', 't', 'l', 'a', 'n', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 't', 'l', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 't', 'l', 'a', 's', 'c', 'o', 'p', 'c', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['a', 't', 'r', 'o', 'c', 'i', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['a', 't', 's', 'i', 'n', 'g', 'a', 'n', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['a', 'u', 'b', 'l', 'y', 's', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['a', 'u', 'c', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'u', 'g', 'u', 's', 't', 'i', 'a'], dtype='<U1'),
#  array(['a', 'u', 'g', 'u', 's', 't', 'y', 'n', 'o', 'l', 'o', 'p', 'h',
#         'u', 's'], dtype='<U1'),
#  array(['a', 'u', 'r', 'o', 'r', 'a', 'c', 'e', 'r', 'a', 't', 'o', 'p',
#         's'], dtype='<U1'),
#  array(['a', 'u', 'r', 'o', 'r', 'n', 'i', 's'], dtype='<U1'),
#  array(['a', 'u', 's', 't', 'r', 'a', 'l', 'o', 'd', 'o', 'c', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'u', 's', 't', 'r', 'a', 'l', 'o', 'v', 'e', 'n', 'a', 't',
#         'o', 'r'], dtype='<U1'),
#  array(['a', 'u', 's', 't', 'r', 'o', 'c', 'h', 'e', 'i', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'u', 's', 't', 'r', 'o', 'p', 'o', 's', 'e', 'i', 'd', 'o',
#         'n'], dtype='<U1'),
#  array(['a', 'u', 's', 't', 'r', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['a', 'u', 's', 't', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['a', 'v', 'a', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'], dtype='<U1'),
#  array(['a', 'v', 'a', 'l', 'o', 'n', 'i', 'a'], dtype='<U1'),
#  array(['a', 'v', 'a', 'l', 'o', 'n', 'i', 'a', 'n', 'u', 's'], dtype='<U1'),
#  array(['a', 'v', 'i', 'a', 't', 'y', 'r', 'a', 'n', 'n', 'i', 's'],
#        dtype='<U1'),
#  array(['a', 'v', 'i', 'm', 'i', 'm', 'u', 's'], dtype='<U1'),
#  array(['a', 'v', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['a', 'v', 'i', 'p', 'e', 's'], dtype='<U1'),
#  array(['a', 'z', 'e', 'n', 'd', 'o', 'h', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'c', 't', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'g', 'a', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'g', 'a', 'r', 'a', 'a', 't', 'a', 'n'], dtype='<U1'),
#  array(['b', 'a', 'h', 'a', 'r', 'i', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'i', 'n', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'k', 'e', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'a', 'l', 'a', 'u', 'r'], dtype='<U1'),
#  array(['b', 'a', 'l', 'o', 'c', 'h', 'i', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'm', 'b', 'i', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['b', 'a', 'n', 'j', 'i'], dtype='<U1'),
#  array(['b', 'a', 'o', 't', 'i', 'a', 'n', 'm', 'a', 'n', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'a', 'r', 'a', 'p', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'r', 'i', 'l', 'i', 'u', 'm'], dtype='<U1'),
#  array(['b', 'a', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'a', 'r', 'r', 'o', 's', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'r', 's', 'b', 'o', 'l', 'd', 'i', 'a'], dtype='<U1'),
#  array(['b', 'a', 'r', 'y', 'o', 'n', 'y', 'x'], dtype='<U1'),
#  array(['b', 'a', 's', 'h', 'u', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 's', 'u', 't', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['b', 'a', 't', 'h', 'y', 'g', 'n', 'a', 't', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 't', 'y', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'a', 'u', 'r', 'u', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['b', 'a', 'y', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'e', 'c', 'k', 'l', 'e', 's', 'p', 'i', 'n', 'a', 'x'],
#        dtype='<U1'),
#  array(['b', 'e', 'e', 'l', 'e', 'm', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['b', 'e', 'i', 'b', 'e', 'i', 'l', 'o', 'n', 'g'], dtype='<U1'),
#  array(['b', 'e', 'i', 'p', 'i', 'a', 'o', 'g', 'n', 'a', 't', 'h', 'u',
#         's'], dtype='<U1'),
#  array(['b', 'e', 'i', 'p', 'i', 'a', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'e', 'i', 's', 'h', 'a', 'n', 'l', 'o', 'n', 'g'], dtype='<U1'),
#  array(['b', 'e', 'l', 'l', 'u', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'e', 'l', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['b', 'e', 'r', 'b', 'e', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'e', 't', 'a', 's', 'u', 'c', 'h', 'u', 's'], dtype='<U1'),
#  array(['b', 'i', 'c', 'e', 'n', 't', 'e', 'n', 'a', 'r', 'i', 'a'],
#        dtype='<U1'),
#  array(['b', 'i', 'e', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'i', 'h', 'a', 'r', 'i', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'i', 'l', 'b', 'e', 'y', 'h', 'a', 'l', 'l', 'o', 'r', 'u',
#         'm'], dtype='<U1'),
#  array(['b', 'i', 's', 's', 'e', 'k', 't', 'i', 'p', 'e', 'l', 't', 'a'],
#        dtype='<U1'),
#  array(['b', 'i', 's', 't', 'a', 'h', 'i', 'e', 'v', 'e', 'r', 's', 'o',
#         'r'], dtype='<U1'),
#  array(['b', 'l', 'a', 'n', 'c', 'o', 'c', 'e', 'r', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'l', 'a', 's', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'l', 'i', 'k', 'a', 'n', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'o', 'l', 'o', 'n', 'g'], dtype='<U1'),
#  array(['b', 'o', 'n', 'a', 'p', 'a', 'r', 't', 'e', 'n', 'y', 'k', 'u',
#         's'], dtype='<U1'),
#  array(['b', 'o', 'n', 'a', 'p', 'a', 'r', 't', 'e', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['b', 'o', 'n', 'a', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['b', 'o', 'n', 'i', 't', 'a', 's', 'a', 'u', 'r', 'a'], dtype='<U1'),
#  array(['b', 'o', 'r', 'e', 'a', 'l', 'o', 'p', 'e', 'l', 't', 'a'],
#        dtype='<U1'),
#  array(['b', 'o', 'r', 'e', 'a', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'o', 'r', 'e', 'o', 'n', 'y', 'k', 'u', 's'], dtype='<U1'),
#  array(['b', 'o', 'r', 'o', 'g', 'o', 'v', 'i', 'a'], dtype='<U1'),
#  array(['b', 'o', 't', 'h', 'r', 'i', 'o', 's', 'p', 'o', 'n', 'd', 'y',
#         'l', 'u', 's'], dtype='<U1'),
#  array(['b', 'r', 'a', 'c', 'h', 'i', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'r', 'a', 'c', 'h', 'y', 'c', 'e', 'r', 'a', 't', 'o', 'p',
#         's'], dtype='<U1'),
#  array(['b', 'r', 'a', 'c', 'h', 'y', 'l', 'o', 'p', 'h', 'o', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'r', 'a', 'c', 'h', 'y', 'p', 'o', 'd', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'r', 'a', 'c', 'h', 'y', 'r', 'o', 'p', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'r', 'a', 'c', 'h', 'y', 't', 'a', 'e', 'n', 'i', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'r', 'a', 'c', 'h', 'y', 't', 'r', 'a', 'c', 'h', 'e', 'l',
#         'o', 'p', 'a', 'n'], dtype='<U1'),
#  array(['b', 'r', 'a', 'd', 'y', 'c', 'n', 'e', 'm', 'e'], dtype='<U1'),
#  array(['b', 'r', 'a', 's', 'i', 'l', 'e', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['b', 'r', 'a', 's', 'i', 'l', 'o', 't', 'i', 't', 'a', 'n'],
#        dtype='<U1'),
#  array(['b', 'r', 'a', 'v', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['b', 'r', 'e', 'v', 'i', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['b', 'r', 'o', 'h', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'r', 'o', 'n', 't', 'o', 'm', 'e', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'r', 'o', 'n', 't', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['b', 'r', 'o', 'n', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'r', 'u', 'h', 'a', 't', 'h', 'k', 'a', 'y', 'o', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['b', 'u', 'g', 'e', 'n', 'a', 's', 'a', 'u', 'r', 'a'], dtype='<U1'),
#  array(['b', 'u', 'i', 't', 'r', 'e', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['b', 'u', 'r', 'i', 'a', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['b', 'u', 'r', 'i', 'o', 'l', 'e', 's', 't', 'e', 's'], dtype='<U1'),
#  array(['b', 'y', 'r', 'a', 'n', 'j', 'a', 'f', 'f', 'i', 'a'], dtype='<U1'),
#  array(['b', 'y', 'r', 'o', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'a', 'e', 'n', 'a', 'g', 'n', 'a', 't', 'h', 'a', 's', 'i',
#         'a'], dtype='<U1'),
#  array(['c', 'a', 'e', 'n', 'a', 'g', 'n', 'a', 't', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'a', 'l', 'a', 'm', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'a', 'l', 'a', 'm', 'o', 's', 'p', 'o', 'n', 'd', 'y', 'l',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'a', 'l', 'a', 'm', 'o', 's', 'p', 'o', 'n', 'd', 'y', 'l',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'a', 'l', 'l', 'o', 'v', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'a', 'm', 'a', 'r', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'a', 'm', 'a', 'r', 'i', 'l', 'l', 'a', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'a', 'm', 'e', 'l', 'o', 't', 'i', 'a'], dtype='<U1'),
#  array(['c', 'a', 'm', 'p', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'a', 'm', 'p', 't', 'o', 'n', 'o', 't', 'u', 's'], dtype='<U1'),
#  array(['c', 'a', 'm', 'p', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'a', 'm', 'p', 'y', 'l', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['c', 'a', 'm', 'p', 'y', 'l', 'o', 'd', 'o', 'n', 'i', 's', 'c',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'a', 'n', 'a', 'r', 'd', 'i', 'a'], dtype='<U1'),
#  array(['c', 'a', 'p', 'i', 't', 'a', 'l', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'a', 'r', 'c', 'h', 'a', 'r', 'o', 'd', 'o', 'n', 't', 'o',
#         's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'a', 'r', 'd', 'i', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['c', 'a', 'r', 'n', 'o', 't', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'a', 's', 'e', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'a', 't', 'h', 'a', 'r', 't', 'e', 's', 'a', 'u', 'r', 'a'],
#        dtype='<U1'),
#  array(['c', 'a', 't', 'h', 'e', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'a', 'u', 'd', 'i', 'p', 't', 'e', 'r', 'y', 'x'], dtype='<U1'),
#  array(['c', 'a', 'u', 'd', 'o', 'c', 'o', 'e', 'l', 'u', 's'], dtype='<U1'),
#  array(['c', 'a', 'u', 'l', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['c', 'e', 'd', 'a', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'e', 'd', 'a', 'r', 'p', 'e', 'l', 't', 'a'], dtype='<U1'),
#  array(['c', 'e', 'd', 'r', 'o', 'r', 'e', 's', 't', 'e', 's'], dtype='<U1'),
#  array(['c', 'e', 'n', 't', 'e', 'm', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['c', 'e', 'n', 't', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'e', 'r', 'a', 's', 'i', 'n', 'o', 'p', 's'], dtype='<U1'),
#  array(['c', 'e', 'r', 'a', 't', 'o', 'n', 'y', 'k', 'u', 's'], dtype='<U1'),
#  array(['c', 'e', 'r', 'a', 't', 'o', 'p', 's'], dtype='<U1'),
#  array(['c', 'e', 'r', 'a', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'e', 't', 'i', 'o', 's', 'a', 'u', 'r', 'i', 's', 'c', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'e', 't', 'i', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'a', 'n', 'g', 'c', 'h', 'u', 'n', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'a', 'n', 'g', 'd', 'u', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'a', 'n', 'g', 'y', 'u', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['c', 'h', 'a', 'o', 'y', 'a', 'n', 'g', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'h', 'a', 'r', 'o', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'a', 's', 'm', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'a', 's', 's', 't', 'e', 'r', 'n', 'b', 'e', 'r', 'g',
#         'i', 'a'], dtype='<U1'),
#  array(['c', 'h', 'e', 'b', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'e', 'n', 'a', 'n', 'i', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'e', 'n', 'e', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'i', 'a', 'l', 'i', 'n', 'g', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'i', 'a', 'y', 'u', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'i', 'e', 'n', 'k', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'i', 'h', 'u', 'a', 'h', 'u', 'a', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'i', 'l', 'a', 'n', 't', 'a', 'i', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'i', 'l', 'e', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'i', 'n', 'd', 'e', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'i', 'n', 'g', 'k', 'a', 'n', 'k', 'o', 'u', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'i', 'n', 's', 'h', 'a', 'k', 'i', 'a', 'n', 'g', 'o',
#         's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'i', 'r', 'o', 's', 't', 'e', 'n', 'o', 't', 'e', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'o', 'c', 'o', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'o', 'n', 'd', 'r', 'o', 's', 't', 'e', 'o', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'r', 'o', 'm', 'o', 'g', 'i', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'h', 'u', 'a', 'n', 'd', 'o', 'n', 'g', 'o', 'c', 'o', 'e',
#         'l', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'u', 'a', 'n', 'j', 'i', 'e', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'h', 'u', 'a', 'n', 'q', 'i', 'l', 'o', 'n', 'g'], dtype='<U1'),
#  array(['c', 'h', 'u', 'b', 'u', 't', 'i', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'h', 'u', 'n', 'g', 'k', 'i', 'n', 'g', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'h', 'u', 'x', 'i', 'o', 'n', 'g', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'i', 'n', 'i', 'z', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'i', 'o', 'n', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['c', 'i', 't', 'i', 'p', 'a', 't', 'i'], dtype='<U1'),
#  array(['c', 'l', 'a', 'd', 'e', 'i', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['c', 'l', 'a', 'o', 'r', 'h', 'y', 'n', 'c', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'l', 'a', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'l', 'a', 'r', 'e', 'n', 'c', 'e', 'a'], dtype='<U1'),
#  array(['c', 'l', 'a', 's', 'm', 'o', 'd', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'l', 'e', 'p', 's', 'y', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'o', 'a', 'h', 'u', 'i', 'l', 'a', 'c', 'e', 'r', 'a', 't',
#         'o', 'p', 's'], dtype='<U1'),
#  array(['c', 'o', 'e', 'l', 'o', 'p', 'h', 'y', 's', 'i', 's'], dtype='<U1'),
#  array(['c', 'o', 'e', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'o', 'e', 'l', 'u', 'r', 'o', 'i', 'd', 'e', 's'], dtype='<U1'),
#  array(['c', 'o', 'e', 'l', 'u', 'r', 'o', 's', 'a', 'u', 'r', 'a', 'v',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'o', 'e', 'l', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'o', 'l', 'e', 'p', 'i', 'o', 'c', 'e', 'p', 'h', 'a', 'l',
#         'e'], dtype='<U1'),
#  array(['c', 'o', 'l', 'o', 'r', 'a', 'd', 'i', 'a'], dtype='<U1'),
#  array(['c', 'o', 'l', 'o', 'r', 'a', 'd', 'i', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'o', 'l', 'o', 's', 's', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'o', 'm', 'a', 'h', 'u', 'e', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'o', 'm', 'a', 'n', 'c', 'h', 'e', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'o', 'm', 'p', 's', 'o', 'g', 'n', 'a', 't', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'o', 'm', 'p', 's', 'o', 's', 'u', 'c', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'o', 'n', 'c', 'a', 'v', 'e', 'n', 'a', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['c', 'o', 'n', 'c', 'h', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['c', 'o', 'n', 'd', 'o', 'r', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['c', 'o', 'r', 'o', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'o', 'r', 'y', 't', 'h', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['c', 'o', 'r', 'y', 't', 'h', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'r', 'a', 's', 'p', 'e', 'd', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['c', 'r', 'a', 't', 'a', 'e', 'o', 'm', 'u', 's'], dtype='<U1'),
#  array(['c', 'r', 'a', 't', 'e', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'r', 'e', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['c', 'r', 'i', 'c', 'h', 't', 'o', 'n', 'p', 'e', 'l', 't', 'a'],
#        dtype='<U1'),
#  array(['c', 'r', 'i', 'c', 'h', 't', 'o', 'n', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'r', 'i', 's', 't', 'a', 't', 'u', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['c', 'r', 'o', 's', 'b', 'y', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'r', 'u', 'x', 'i', 'c', 'h', 'e', 'i', 'r', 'o', 's'],
#        dtype='<U1'),
#  array(['c', 'r', 'y', 'o', 'l', 'o', 'p', 'h', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['c', 'r', 'y', 'p', 't', 'o', 'd', 'r', 'a', 'c', 'o'], dtype='<U1'),
#  array(['c', 'r', 'y', 'p', 't', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['c', 'r', 'y', 'p', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['c', 'r', 'y', 'p', 't', 'o', 'v', 'o', 'l', 'a', 'n', 's'],
#        dtype='<U1'),
#  array(['c', 'u', 'm', 'n', 'o', 'r', 'i', 'a'], dtype='<U1'),
#  array(['d', 'a', 'a', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'a', 'c', 'e', 'n', 't', 'r', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'a', 'c', 'h', 'o', 'n', 'g', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['d', 'a', 'e', 'm', 'o', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'a', 'h', 'a', 'l', 'o', 'k', 'e', 'l', 'y'], dtype='<U1'),
#  array(['d', 'a', 'k', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'a', 'k', 'o', 't', 'a', 'd', 'o', 'n'], dtype='<U1'),
#  array(['d', 'a', 'k', 'o', 't', 'a', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['d', 'a', 'l', 'i', 'a', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'a', 'm', 'a', 'l', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'a', 'n', 'd', 'a', 'k', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'a', 'n', 'u', 'b', 'i', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'a', 'p', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'a', 'r', 'w', 'i', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'a', 's', 'h', 'a', 'n', 'p', 'u', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['d', 'a', 's', 'p', 'l', 'e', 't', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['d', 'a', 's', 'y', 'g', 'n', 'a', 't', 'h', 'o', 'i', 'd', 'e',
#         's'], dtype='<U1'),
#  array(['d', 'a', 's', 'y', 'g', 'n', 'a', 't', 'h', 'u', 's'], dtype='<U1'),
#  array(['d', 'a', 't', 'a', 'n', 'g', 'l', 'o', 'n', 'g'], dtype='<U1'),
#  array(['d', 'a', 't', 'o', 'n', 'g', 'l', 'o', 'n', 'g'], dtype='<U1'),
#  array(['d', 'a', 't', 'o', 'u', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'a', 'u', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'a', 'x', 'i', 'a', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['d', 'e', 'i', 'n', 'o', 'c', 'h', 'e', 'i', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'e', 'i', 'n', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['d', 'e', 'i', 'n', 'o', 'n', 'y', 'c', 'h', 'u', 's'], dtype='<U1'),
#  array(['d', 'e', 'l', 'a', 'p', 'p', 'a', 'r', 'e', 'n', 't', 'i', 'a'],
#        dtype='<U1'),
#  array(['d', 'e', 'l', 't', 'a', 'd', 'r', 'o', 'm', 'e', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'e', 'm', 'a', 'n', 'd', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'e', 'n', 'v', 'e', 'r', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'e', 'u', 't', 'e', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'i', 'a', 'b', 'l', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p',
#         's'], dtype='<U1'),
#  array(['d', 'i', 'a', 'm', 'a', 'n', 't', 'i', 'n', 'a', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'i', 'a', 'n', 'c', 'h', 'u', 'n', 'g', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'i', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'], dtype='<U1'),
#  array(['d', 'i', 'c', 'e', 'r', 'a', 't', 'u', 's', 'd', 'i', 'c', 'l',
#         'o', 'n', 'i', 'u', 's'], dtype='<U1'),
#  array(['d', 'i', 'c', 'r', 'a', 'e', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'i', 'd', 'a', 'n', 'o', 'd', 'o', 'n', 'd', 'i', 'l', 'o',
#         'n', 'g'], dtype='<U1'),
#  array(['d', 'i', 'l', 'o', 'p', 'h', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'i', 'l', 'u', 'v', 'i', 'c', 'u', 'r', 's', 'o', 'r'],
#        dtype='<U1'),
#  array(['d', 'i', 'm', 'o', 'd', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'i', 'n', 'h', 'e', 'i', 'r', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['d', 'i', 'n', 'o', 'd', 'o', 'c', 'u', 's'], dtype='<U1'),
#  array(['d', 'i', 'n', 'o', 't', 'y', 'r', 'a', 'n', 'n', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'i', 'p', 'l', 'o', 'd', 'o', 'c', 'u', 's'], dtype='<U1'),
#  array(['d', 'i', 'p', 'l', 'o', 't', 'o', 'm', 'o', 'd', 'o', 'n'],
#        dtype='<U1'),
#  array(['d', 'i', 'r', 'a', 'c', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['d', 'o', 'l', 'i', 'c', 'h', 'o', 's', 'u', 'c', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'o', 'l', 'l', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['d', 'o', 'm', 'e', 'y', 'k', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'o', 'n', 'g', 'b', 'e', 'i', 't', 'i', 't', 'a', 'n'],
#        dtype='<U1'),
#  array(['d', 'o', 'n', 'g', 'y', 'a', 'n', 'g', 'o', 'p', 'e', 'l', 't',
#         'a'], dtype='<U1'),
#  array(['d', 'o', 'n', 'g', 'y', 'a', 'n', 'g', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['d', 'o', 'r', 'a', 't', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['d', 'o', 'r', 'y', 'p', 'h', 'o', 'r', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['d', 'r', 'a', 'c', 'o', 'n', 'y', 'x'], dtype='<U1'),
#  array(['d', 'r', 'a', 'c', 'o', 'p', 'e', 'l', 't', 'a'], dtype='<U1'),
#  array(['d', 'r', 'a', 'c', 'o', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['d', 'r', 'a', 'c', 'o', 'r', 'e', 'x'], dtype='<U1'),
#  array(['d', 'r', 'a', 'c', 'o', 'v', 'e', 'n', 'a', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['d', 'r', 'a', 'v', 'i', 'd', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'r', 'e', 'a', 'd', 'n', 'o', 'u', 'g', 'h', 't', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'r', 'i', 'n', 'k', 'e', 'r'], dtype='<U1'),
#  array(['d', 'r', 'o', 'm', 'a', 'e', 'o', 's', 'a', 'u', 'r', 'o', 'i',
#         'd', 'e', 's'], dtype='<U1'),
#  array(['d', 'r', 'o', 'm', 'a', 'e', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'r', 'o', 'm', 'i', 'c', 'e', 'i', 'o', 'm', 'i', 'm', 'u',
#         's'], dtype='<U1'),
#  array(['d', 'r', 'o', 'm', 'i', 'c', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'r', 'u', 's', 'i', 'l', 'a', 's', 'a', 'u', 'r', 'a'],
#        dtype='<U1'),
#  array(['d', 'r', 'y', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'r', 'y', 'p', 't', 'o', 's', 'a', 'u', 'r', 'o', 'i', 'd',
#         'e', 's'], dtype='<U1'),
#  array(['d', 'r', 'y', 'p', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'u', 'b', 'r', 'e', 'u', 'i', 'l', 'l', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['d', 'u', 'r', 'i', 'a', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['d', 'u', 'r', 'i', 'a', 'v', 'e', 'n', 'a', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['d', 'y', 'n', 'a', 'm', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'y', 'o', 'p', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'y', 's', 'a', 'l', 'o', 't', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['d', 'y', 's', 'g', 'a', 'n', 'u', 's'], dtype='<U1'),
#  array(['d', 'y', 's', 'l', 'o', 'c', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'y', 's', 't', 'r', 'o', 'p', 'h', 'a', 'e', 'u', 's'],
#        dtype='<U1'),
#  array(['d', 'y', 's', 't', 'y', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'c', 'h', 'i', 'n', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['e', 'd', 'm', 'a', 'r', 'k', 'a'], dtype='<U1'),
#  array(['e', 'd', 'm', 'o', 'n', 't', 'o', 'n', 'i', 'a'], dtype='<U1'),
#  array(['e', 'd', 'm', 'o', 'n', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'f', 'r', 'a', 'a', 's', 'i', 'a'], dtype='<U1'),
#  array(['e', 'i', 'n', 'i', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['e', 'k', 'r', 'i', 'x', 'i', 'n', 'a', 't', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['e', 'l', 'a', 'c', 'h', 'i', 's', 't', 'o', 's', 'u', 'c', 'h',
#         'u', 's'], dtype='<U1'),
#  array(['e', 'l', 'a', 'l', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['e', 'l', 'a', 'p', 'h', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'l', 'm', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['e', 'l', 'o', 'p', 't', 'e', 'r', 'y', 'x'], dtype='<U1'),
#  array(['e', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['e', 'l', 'r', 'h', 'a', 'z', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'l', 'v', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['e', 'm', 'a', 'u', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['e', 'm', 'b', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['e', 'n', 'i', 'g', 'm', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'o', 'a', 'b', 'e', 'l', 'i', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'o', 'b', 'r', 'o', 'n', 't', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['e', 'o', 'c', 'a', 'r', 'c', 'h', 'a', 'r', 'i', 'a'], dtype='<U1'),
#  array(['e', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'], dtype='<U1'),
#  array(['e', 'o', 'c', 'u', 'r', 's', 'o', 'r'], dtype='<U1'),
#  array(['e', 'o', 'd', 'r', 'o', 'm', 'a', 'e', 'u', 's'], dtype='<U1'),
#  array(['e', 'o', 'h', 'a', 'd', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'o', 'l', 'a', 'm', 'b', 'i', 'a'], dtype='<U1'),
#  array(['e', 'o', 'm', 'a', 'm', 'e', 'n', 'c', 'h', 'i', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['e', 'o', 'p', 'l', 'o', 'p', 'h', 'y', 's', 'i', 's'], dtype='<U1'),
#  array(['e', 'o', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['e', 'o', 's', 'i', 'n', 'o', 'p', 't', 'e', 'r', 'y', 'x'],
#        dtype='<U1'),
#  array(['e', 'o', 't', 'r', 'a', 'c', 'h', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['e', 'o', 't', 'r', 'i', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['e', 'o', 't', 'y', 'r', 'a', 'n', 'n', 'u', 's'], dtype='<U1'),
#  array(['e', 'o', 'u', 's', 'd', 'r', 'y', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['e', 'p', 'a', 'c', 'h', 't', 'h', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['e', 'p', 'a', 'n', 't', 'e', 'r', 'i', 'a', 's'], dtype='<U1'),
#  array(['e', 'p', 'h', 'o', 'e', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'p', 'i', 'c', 'a', 'm', 'p', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['e', 'p', 'i', 'c', 'h', 'i', 'r', 'o', 's', 't', 'e', 'n', 'o',
#         't', 'e', 's'], dtype='<U1'),
#  array(['e', 'p', 'i', 'd', 'e', 'n', 'd', 'r', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['e', 'p', 'i', 'd', 'e', 'x', 'i', 'p', 't', 'e', 'r', 'y', 'x'],
#        dtype='<U1'),
#  array(['e', 'q', 'u', 'i', 'j', 'u', 'b', 'u', 's'], dtype='<U1'),
#  array(['e', 'r', 'e', 'c', 't', 'o', 'p', 'u', 's'], dtype='<U1'),
#  array(['e', 'r', 'k', 'e', 't', 'u'], dtype='<U1'),
#  array(['e', 'r', 'l', 'i', 'a', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'r', 'l', 'i', 'k', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 's', 'h', 'a', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'u', 'a', 'c', 'a', 'n', 't', 'h', 'u', 's'], dtype='<U1'),
#  array(['e', 'u', 'c', 'a', 'm', 'e', 'r', 'o', 't', 'u', 's'], dtype='<U1'),
#  array(['e', 'u', 'c', 'e', 'n', 't', 'r', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['e', 'u', 'c', 'e', 'r', 'c', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'u', 'c', 'n', 'e', 'm', 'e', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'u', 'c', 'o', 'e', 'l', 'o', 'p', 'h', 'y', 's', 'i', 's'],
#        dtype='<U1'),
#  array(['e', 'u', 'g', 'o', 'n', 'g', 'b', 'u', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['e', 'u', 'h', 'e', 'l', 'o', 'p', 'u', 's'], dtype='<U1'),
#  array(['e', 'u', 'o', 'p', 'l', 'o', 'c', 'e', 'p', 'h', 'a', 'l', 'u',
#         's'], dtype='<U1'),
#  array(['e', 'u', 'p', 'o', 'd', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'u', 'r', 'e', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['e', 'u', 'r', 'o', 'l', 'i', 'm', 'n', 'o', 'r', 'n', 'i', 's'],
#        dtype='<U1'),
#  array(['e', 'u', 'r', 'o', 'n', 'y', 'c', 'h', 'o', 'd', 'o', 'n'],
#        dtype='<U1'),
#  array(['e', 'u', 'r', 'o', 'p', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'u', 'r', 'o', 'p', 'a', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['e', 'u', 'r', 'o', 'p', 'e', 'l', 't', 'a'], dtype='<U1'),
#  array(['e', 'u', 's', 'k', 'e', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['e', 'u', 's', 't', 'r', 'e', 'p', 't', 'o', 's', 'p', 'o', 'n',
#         'd', 'y', 'l', 'u', 's'], dtype='<U1'),
#  array(['f', 'a', 'b', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['f', 'a', 'l', 'c', 'a', 'r', 'i', 'u', 's'], dtype='<U1'),
#  array(['f', 'e', 'n', 'd', 'u', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['f', 'e', 'n', 'e', 's', 't', 'r', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['f', 'e', 'r', 'g', 'a', 'n', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['f', 'e', 'r', 'g', 'a', 'n', 'a', 's', 't', 'e', 'g', 'o', 's'],
#        dtype='<U1'),
#  array(['f', 'e', 'r', 'g', 'a', 'n', 'o', 'c', 'e', 'p', 'h', 'a', 'l',
#         'e'], dtype='<U1'),
#  array(['f', 'o', 'r', 'a', 'm', 'i', 'n', 'a', 'c', 'e', 'p', 'h', 'a',
#         'l', 'e'], dtype='<U1'),
#  array(['f', 'o', 's', 't', 'e', 'r', 'o', 'v', 'e', 'n', 'a', 't', 'o',
#         'r'], dtype='<U1'),
#  array(['f', 'r', 'e', 'n', 'g', 'u', 'e', 'l', 'l', 'i', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['f', 'r', 'u', 'i', 't', 'a', 'd', 'e', 'n', 's'], dtype='<U1'),
#  array(['f', 'u', 'k', 'u', 'i', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['f', 'u', 'k', 'u', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['f', 'u', 'k', 'u', 'i', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['f', 'u', 'k', 'u', 'i', 'v', 'e', 'n', 'a', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['f', 'u', 'l', 'e', 'n', 'g', 'i', 'a'], dtype='<U1'),
#  array(['f', 'u', 'l', 'g', 'u', 'r', 'o', 't', 'h', 'e', 'r', 'i', 'u',
#         'm'], dtype='<U1'),
#  array(['f', 'u', 's', 'i', 'n', 'a', 's', 'u', 's'], dtype='<U1'),
#  array(['f', 'u', 's', 'u', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['f', 'u', 't', 'a', 'b', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['f', 'u', 't', 'a', 'l', 'o', 'g', 'n', 'k', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['g', 'a', 'd', 'o', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'a', 'l', 'e', 'a', 'm', 'o', 'p', 'u', 's'], dtype='<U1'),
#  array(['g', 'a', 'l', 'e', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['g', 'a', 'l', 'l', 'i', 'm', 'i', 'm', 'u', 's'], dtype='<U1'),
#  array(['g', 'a', 'l', 't', 'o', 'n', 'i', 'a'], dtype='<U1'),
#  array(['g', 'a', 'l', 'v', 'e', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'a', 'l', 'v', 'e', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['g', 'a', 'n', 'n', 'a', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'a', 'n', 's', 'u', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['g', 'a', 'n', 'z', 'h', 'o', 'u', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'a', 'r', 'g', 'o', 'y', 'l', 'e', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['g', 'a', 'r', 'u', 'd', 'i', 'm', 'i', 'm', 'u', 's'], dtype='<U1'),
#  array(['g', 'a', 's', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['g', 'a', 's', 'p', 'a', 'r', 'i', 'n', 'i', 's', 'a', 'u', 'r',
#         'a'], dtype='<U1'),
#  array(['g', 'a', 's', 't', 'o', 'n', 'i', 'a'], dtype='<U1'),
#  array(['g', 'a', 'v', 'i', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'e', 'm', 'i', 'n', 'i', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['g', 'e', 'n', 'u', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['g', 'e', 'n', 'y', 'o', 'd', 'e', 'c', 't', 'e', 's'], dtype='<U1'),
#  array(['g', 'e', 'r', 'a', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'i', 'd', 'e', 'o', 'n', 'm', 'a', 'n', 't', 'e', 'l', 'l',
#         'i', 'a'], dtype='<U1'),
#  array(['g', 'i', 'g', 'a', 'n', 'o', 't', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['g', 'i', 'g', 'a', 'n', 't', 'o', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['g', 'i', 'g', 'a', 'n', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'i', 'g', 'a', 'n', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'i', 'g', 'a', 'n', 't', 'o', 's', 'c', 'e', 'l', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'i', 'g', 'a', 'n', 't', 's', 'p', 'i', 'n', 'o', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['g', 'i', 'l', 'm', 'o', 'r', 'e', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['g', 'i', 'n', 'n', 'a', 'r', 'e', 'e', 'm', 'i', 'm', 'u', 's'],
#        dtype='<U1'),
#  array(['g', 'i', 'r', 'a', 'f', 'f', 'a', 't', 'i', 't', 'a', 'n'],
#        dtype='<U1'),
#  array(['g', 'l', 'a', 'c', 'i', 'a', 'l', 'i', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['g', 'l', 'i', 's', 'h', 'a', 'd', 'e', 's'], dtype='<U1'),
#  array(['g', 'l', 'y', 'p', 't', 'o', 'd', 'o', 'n', 't', 'o', 'p', 'e',
#         'l', 't', 'a'], dtype='<U1'),
#  array(['s', 'k', 'e', 'l', 'e', 't', 'o', 'n'], dtype='<U1'),
#  array(['g', 'o', 'b', 'i', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['g', 'o', 'b', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['g', 'o', 'b', 'i', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
# ...
#         'o', 'n'], dtype='<U1'),
#  array(['m', 'a', 'c', 'r', 'o', 'g', 'r', 'y', 'p', 'h', 'o', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'c', 'r', 'o', 'p', 'h', 'a', 'l', 'a', 'n', 'g', 'i',
#         'a'], dtype='<U1'),
#  array(['m', 'a', 'c', 'r', 'o', 's', 'c', 'e', 'l', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'c', 'r', 'u', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'd', 's', 'e', 'n', 'i', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'g', 'n', 'a', 'p', 'a', 'u', 'l', 'i', 'a'], dtype='<U1'),
#  array(['m', 'a', 'g', 'n', 'a', 'm', 'a', 'n', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'g', 'n', 'i', 'r', 'o', 's', 't', 'r', 'i', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'g', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'g', 'u', 'l', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['m', 'a', 'g', 'y', 'a', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'h', 'a', 'k', 'a', 'l', 'a'], dtype='<U1'),
#  array(['m', 'a', 'i', 'a', 's', 'a', 'u', 'r', 'a'], dtype='<U1'),
#  array(['m', 'a', 'j', 'u', 'n', 'g', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'j', 'u', 'n', 'g', 'a', 't', 'h', 'o', 'l', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'l', 'a', 'r', 'g', 'u', 'e', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['m', 'a', 'l', 'a', 'w', 'i', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'l', 'e', 'e', 'v', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'l', 'e', 'e', 'v', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'm', 'e', 'n', 'c', 'h', 'i', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['m', 'a', 'n', 'i', 'd', 'e', 'n', 's'], dtype='<U1'),
#  array(['m', 'a', 'n', 'd', 's', 'c', 'h', 'u', 'r', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'n', 'o', 's', 'p', 'o', 'n', 'd', 'y', 'l', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'n', 't', 'e', 'l', 'l', 'i', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['m', 'a', 'n', 't', 'e', 'l', 'l', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['m', 'a', 'p', 'u', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'r', 'a', 's', 'u', 'c', 'h', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'r', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'r', 'm', 'a', 'r', 'o', 's', 'p', 'o', 'n', 'd', 'y',
#         'l', 'u', 's'], dtype='<U1'),
#  array(['m', 'a', 'r', 's', 'h', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 'r', 't', 'h', 'a', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['m', 'a', 's', 'i', 'a', 'k', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'a', 's', 's', 'o', 's', 'p', 'o', 'n', 'd', 'y', 'l', 'u',
#         's'], dtype='<U1'),
#  array(['m', 'a', 't', 'h', 'e', 'r', 'o', 'n', 'o', 'd', 'o', 'n'],
#        dtype='<U1'),
#  array(['m', 'a', 'x', 'a', 'k', 'a', 'l', 'i', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['m', 'e', 'd', 'u', 's', 'a', 'c', 'e', 'r', 'a', 't', 'o', 'p',
#         's'], dtype='<U1'),
#  array(['m', 'e', 'g', 'a', 'c', 'e', 'r', 'v', 'i', 'x', 'o', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'e', 'g', 'a', 'd', 'a', 'c', 't', 'y', 'l', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'e', 'g', 'a', 'd', 'o', 'n', 't', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['m', 'e', 'g', 'a', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'e', 'g', 'a', 'p', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'e', 'g', 'a', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['m', 'e', 'i'], dtype='<U1'),
#  array(['m', 'e', 'l', 'a', 'n', 'o', 'r', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['m', 'e', 'n', 'd', 'o', 'z', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'e', 'r', 'c', 'u', 'r', 'i', 'c', 'e', 'r', 'a', 't', 'o',
#         'p', 's'], dtype='<U1'),
#  array(['m', 'e', 'r', 'o', 'k', 't', 'e', 'n', 'o', 's'], dtype='<U1'),
#  array(['m', 'e', 't', 'r', 'i', 'a', 'c', 'a', 'n', 't', 'h', 'o', 's',
#         'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'c', 'e', 'p', 'h', 'a', 'l', 'e'],
#        dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'c', 'e', 'r', 'a', 't', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'c', 'o', 'e', 'l', 'u', 's'], dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'd', 'o', 'n', 't', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'h', 'a', 'd', 'r', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'p', 'a', 'c', 'h', 'y', 'c', 'e', 'p',
#         'h', 'a', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['m', 'i', 'c', 'r', 'o', 'v', 'e', 'n', 'a', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['m', 'i', 'e', 'r', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'i', 'f', 'u', 'n', 'e', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'i', 'n', 'm', 'i'], dtype='<U1'),
#  array(['m', 'i', 'n', 'o', 't', 'a', 'u', 'r', 'a', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['m', 'i', 'r', 'a', 'g', 'a', 'i', 'a'], dtype='<U1'),
#  array(['m', 'i', 'r', 'i', 's', 'c', 'h', 'i', 'a'], dtype='<U1'),
#  array(['m', 'o', 'a', 'b', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'o', 'c', 'h', 'l', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['m', 'o', 'h', 'a', 'm', 'm', 'a', 'd', 'i', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['m', 'o', 'j', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['m', 'o', 'n', 'g', 'o', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'o', 'n', 'k', 'o', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'o', 'n', 'o', 'c', 'l', 'o', 'n', 'i', 'u', 's'], dtype='<U1'),
#  array(['m', 'o', 'n', 'o', 'l', 'o', 'p', 'h', 'o', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['m', 'o', 'n', 'o', 'n', 'y', 'c', 'h', 'u', 's'], dtype='<U1'),
#  array(['m', 'o', 'n', 'o', 'n', 'y', 'k', 'u', 's'], dtype='<U1'),
#  array(['m', 'o', 'n', 't', 'a', 'n', 'o', 'c', 'e', 'r', 'a', 't', 'o',
#         'p', 's'], dtype='<U1'),
#  array(['m', 'o', 'r', 'e', 'l', 'l', 'a', 'd', 'o', 'n'], dtype='<U1'),
#  array(['m', 'o', 'r', 'i', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'o', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'o', 'r', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'o', 's', 'a', 'i', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['m', 'o', 's', 'h', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 't', 'a', 'p', 'a', 'i', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 't', 'o', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'u', 'r', 'u', 's', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['m', 'u', 's', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'u', 't', 't', 'a', 'b', 'u', 'r', 'r', 'a', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['m', 'u', 'y', 'e', 'l', 'e', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['m', 'y', 'm', 'o', 'o', 'r', 'a', 'p', 'e', 'l', 't', 'a'],
#        dtype='<U1'),
#  array(['n', 'a', 'a', 's', 'h', 'o', 'i', 'b', 'i', 't', 'o', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'a', 'm', 'b', 'a', 'l', 'i', 'a'], dtype='<U1'),
#  array(['n', 'a', 'n', 'k', 'a', 'n', 'g', 'i', 'a'], dtype='<U1'),
#  array(['n', 'a', 'n', 'n', 'i', 'n', 'g', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['n', 'a', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'a', 'n', 'o', 't', 'y', 'r', 'a', 'n', 'n', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'a', 'n', 's', 'h', 'i', 'u', 'n', 'g', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'a', 'n', 'u', 'q', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'a', 'n', 'y', 'a', 'n', 'g', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['n', 'a', 'r', 'a', 'm', 'b', 'u', 'e', 'n', 'a', 't', 'i', 't',
#         'a', 'n'], dtype='<U1'),
#  array(['n', 'a', 's', 'u', 't', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p',
#         's'], dtype='<U1'),
#  array(['n', 'a', 't', 'r', 'o', 'n', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'e', 'b', 'u', 'l', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'e', 'c', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'e', 'd', 'c', 'o', 'l', 'b', 'e', 'r', 't', 'i', 'a'],
#        dtype='<U1'),
#  array(['n', 'e', 'd', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['n', 'e', 'i', 'm', 'o', 'n', 'g', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['n', 'e', 'm', 'e', 'g', 't', 'i', 'a'], dtype='<U1'),
#  array(['n', 'e', 'm', 'e', 'g', 't', 'o', 'm', 'a', 'i', 'a'], dtype='<U1'),
#  array(['n', 'e', 'm', 'e', 'g', 't', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'e', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'e', 'o', 's', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['n', 'e', 'o', 'v', 'e', 'n', 'a', 't', 'o', 'r'], dtype='<U1'),
#  array(['n', 'e', 'u', 'q', 'u', 'e', 'n', 'r', 'a', 'p', 't', 'o', 'r'],
#        dtype='<U1'),
#  array(['n', 'e', 'u', 'q', 'u', 'e', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'e', 'w', 't', 'o', 'n', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'g', 'e', 'x', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'i', 'c', 'k', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'i', 'g', 'e', 'r', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'i', 'n', 'g', 'y', 'u', 'a', 'n', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['n', 'i', 'o', 'b', 'r', 'a', 'r', 'a', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['n', 'i', 'p', 'p', 'o', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'o', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'o', 'd', 'o', 'c', 'e', 'p', 'h', 'a', 'l', 'o', 's', 'a',
#         'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'o', 'd', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'o', 'm', 'i', 'n', 'g', 'i', 'a'], dtype='<U1'),
#  array(['n', 'o', 'p', 'c', 's', 'a', 's', 'p', 'o', 'n', 'd', 'y', 'l',
#         'u', 's'], dtype='<U1'),
#  array(['n', 'o', 'r', 'm', 'a', 'n', 'n', 'i', 'a', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['n', 'o', 't', 'h', 'r', 'o', 'n', 'y', 'c', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'o', 't', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['n', 'o', 't', 'o', 'c', 'o', 'l', 'o', 's', 's', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'o', 't', 'o', 'h', 'y', 'p', 's', 'i', 'l', 'o', 'p', 'h',
#         'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['n', 'q', 'w', 'e', 'b', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 't', 'e', 'r', 'e', 'g', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['n', 'u', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'u', 't', 'h', 'e', 't', 'e', 's'], dtype='<U1'),
#  array(['n', 'y', 'a', 's', 'a', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['n', 'y', 'o', 'r', 'o', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'h', 'm', 'd', 'e', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'j', 'o', 'c', 'e', 'r', 'a', 't', 'o', 'p', 's'], dtype='<U1'),
#  array(['o', 'j', 'o', 'r', 'a', 'p', 't', 'o', 'r', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['o', 'l', 'i', 'g', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'l', 'o', 'r', 'o', 't', 'i', 't', 'a', 'n'], dtype='<U1'),
#  array(['o', 'm', 'e', 'i', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'm', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'n', 'y', 'c', 'h', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'o', 'h', 'k', 'o', 't', 'o', 'k', 'i', 'a'], dtype='<U1'),
#  array(['o', 'p', 'i', 's', 't', 'h', 'o', 'c', 'o', 'e', 'l', 'i', 'c',
#         'a', 'u', 'd', 'i', 'a'], dtype='<U1'),
#  array(['o', 'p', 'l', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'r', 'c', 'o', 'm', 'i', 'm', 'u', 's'], dtype='<U1'),
#  array(['o', 'r', 'i', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's', 'o', 'r',
#         'k', 'o', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['o', 'r', 'n', 'a', 't', 'o', 't', 'h', 'o', 'l', 'u', 's', 'o',
#         'r', 'n', 'i', 't', 'h', 'o', 'd', 'e', 's', 'm', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'r', 'n', 'i', 't', 'h', 'o', 'i', 'd', 'e', 's'], dtype='<U1'),
#  array(['o', 'r', 'n', 'i', 't', 'h', 'o', 'l', 'e', 's', 't', 'e', 's'],
#        dtype='<U1'),
#  array(['o', 'r', 'n', 'i', 't', 'h', 'o', 'm', 'e', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'r', 'n', 'i', 't', 'h', 'o', 'm', 'i', 'm', 'o', 'i', 'd',
#         'e', 's'], dtype='<U1'),
#  array(['o', 'r', 'n', 'i', 't', 'h', 'o', 'm', 'i', 'm', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'r', 'n', 'i', 't', 'h', 'o', 'p', 's', 'i', 's'], dtype='<U1'),
#  array(['o', 'r', 'n', 'i', 't', 'h', 'o', 's', 'u', 'c', 'h', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'r', 'n', 'i', 't', 'h', 'o', 't', 'a', 'r', 's', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'r', 'o', 'd', 'r', 'o', 'm', 'e', 'u', 's'], dtype='<U1'),
#  array(['o', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'r', 't', 'h', 'o', 'g', 'o', 'n', 'i', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'r', 't', 'h', 'o', 'm', 'e', 'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'r', 'y', 'c', 't', 'o', 'd', 'r', 'o', 'm', 'e', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 's', 'h', 'a', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 's', 'm', 'a', 'k', 'a', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 's', 't', 'a', 'f', 'r', 'i', 'k', 'a', 's', 'a', 'u', 'r',
#         'u', 's'], dtype='<U1'),
#  array(['o', 's', 't', 'r', 'o', 'm', 'i', 'a'], dtype='<U1'),
#  array(['o', 't', 'h', 'n', 'i', 'e', 'l', 'i', 'a'], dtype='<U1'),
#  array(['o', 't', 'h', 'n', 'i', 'e', 'l', 'o', 's', 'a', 'u', 'r', 'u',
#         's'], dtype='<U1'),
#  array(['o', 't', 'o', 'g', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'u', 'r', 'a', 'n', 'o', 's', 'a', 'u', 'r', 'u', 's'],
#        dtype='<U1'),
#  array(['o', 'v', 'e', 'r', 'o', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['o', 'v', 'i', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['o', 'v', 'o', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['o', 'w', 'e', 'n', 'o', 'd', 'o', 'n'], dtype='<U1'),
#  array(['o', 'x', 'a', 'l', 'a', 'i', 'a'], dtype='<U1'),
#  array(['o', 'z', 'r', 'a', 'p', 't', 'o', 'r'], dtype='<U1'),
#  array(['p', 'a', 'c', 'h', 'y', 'c', 'e', 'p', 'h', 'a', 'l', 'o', 's',
#         'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  array(['p', 'a', 'c', 'h', 'y', 'r', 'h', 'i', 'n', 'o', 's', 'a', 'u',
#         'r', 'u', 's'], dtype='<U1'),
#  array(['p', 'a', 'c', 'h', 'y', 's', 'a', 'u', 'r', 'i', 's', 'c', 'u',
#         's'], dtype='<U1'),
#  array(['p', 'a', 'c', 'h', 'y', 's', 'a', 'u', 'r', 'o', 'p', 's'],
#        dtype='<U1'),
#  array(['p', 'a', 'c', 'h', 'y', 's', 'a', 'u', 'r', 'u', 's'], dtype='<U1'),
#  ...]

# %%
all_chars=set()
all_chars.add('\n')
for name in char_list:
  for ch in name:
    all_chars.add(ch)
chars=sorted(list(all_chars))

# %%
chars
# Out:
# ['\n',
#  np.str_('a'),
#  np.str_('b'),
#  np.str_('c'),
#  np.str_('d'),
#  np.str_('e'),
#  np.str_('f'),
#  np.str_('g'),
#  np.str_('h'),
#  np.str_('i'),
#  np.str_('j'),
#  np.str_('k'),
#  np.str_('l'),
#  np.str_('m'),
#  np.str_('n'),
#  np.str_('o'),
#  np.str_('p'),
#  np.str_('q'),
#  np.str_('r'),
#  np.str_('s'),
#  np.str_('t'),
#  np.str_('u'),
#  np.str_('v'),
#  np.str_('w'),
#  np.str_('x'),
#  np.str_('y'),
#  np.str_('z')]

# %%
char_to_ix={ch:i for i,ch in enumerate(chars)}
ix_to_char={i:ch for i,ch in enumerate(chars)}

# %%
char_to_ix
# Out:
# {'\n': 0,
#  np.str_('a'): 1,
#  np.str_('b'): 2,
#  np.str_('c'): 3,
#  np.str_('d'): 4,
#  np.str_('e'): 5,
#  np.str_('f'): 6,
#  np.str_('g'): 7,
#  np.str_('h'): 8,
#  np.str_('i'): 9,
#  np.str_('j'): 10,
#  np.str_('k'): 11,
#  np.str_('l'): 12,
#  np.str_('m'): 13,
#  np.str_('n'): 14,
#  np.str_('o'): 15,
#  np.str_('p'): 16,
#  np.str_('q'): 17,
#  np.str_('r'): 18,
#  np.str_('s'): 19,
#  np.str_('t'): 20,
#  np.str_('u'): 21,
#  np.str_('v'): 22,
#  np.str_('w'): 23,
#  np.str_('x'): 24,
#  np.str_('y'): 25,
#  np.str_('z'): 26}

# %%
ix_to_char
# Out:
# {0: '\n',
#  1: np.str_('a'),
#  2: np.str_('b'),
#  3: np.str_('c'),
#  4: np.str_('d'),
#  5: np.str_('e'),
#  6: np.str_('f'),
#  7: np.str_('g'),
#  8: np.str_('h'),
#  9: np.str_('i'),
#  10: np.str_('j'),
#  11: np.str_('k'),
#  12: np.str_('l'),
#  13: np.str_('m'),
#  14: np.str_('n'),
#  15: np.str_('o'),
#  16: np.str_('p'),
#  17: np.str_('q'),
#  18: np.str_('r'),
#  19: np.str_('s'),
#  20: np.str_('t'),
#  21: np.str_('u'),
#  22: np.str_('v'),
#  23: np.str_('w'),
#  24: np.str_('x'),
#  25: np.str_('y'),
#  26: np.str_('z')}

# %%
name = char_list[0]
print(name)
# Out:
# ['a' 'a' 'c' 'h' 'e' 'n' 'o' 's' 'a' 'u' 'r' 'u' 's']

# %%
X = [char_to_ix[ch] for ch in name]
Y = [char_to_ix[ch] for ch in name[1:]] + [char_to_ix['\n']]

print("X:", np.shape(np.array(X)))
print("Y:", np.shape(np.array(Y)))
print("X:", X)
print("Y:", Y)
# Out:
# X: (13,)
# Y: (13,)
# X: [1, 1, 3, 8, 5, 14, 15, 19, 1, 21, 18, 21, 19]
# Y: [1, 3, 8, 5, 14, 15, 19, 1, 21, 18, 21, 19, 0]

# %% [markdown]
# Model Architecture

# %%
import numpy as np
# hidden layer with activation function
class Hidden_Layer:
  def __init__(self,vocab_size,embed_size,hidden_size):
    #hidden_size is nothing but no. neurons
    self.bias=np.zeros((1,hidden_size))
    #Embeddingtable
    self.Wex=np.random.randn(vocab_size,embed_size)*0.01
    #Hidden-Hidden weights
    self.Whh=np.random.randn(hidden_size,hidden_size)*0.01
    # Embed-Hidden weights
    self.Wxh=np.random.randn(embed_size,hidden_size)*0.01

  def forward(self,X_idx,h0=None):
    T=len(X_idx)
    H=self.Whh.shape[0]
    if h0 is None:
      h_prev=np.zeros((1,H))
    else:
      h_prev=h0.reshape(1,H)
    hs=np.zeros((T, H))
    self.cache=[]
    for t in range(T):
      idx=X_idx[t]
      e_t=self.Wex[idx:idx+1, :]
      a_t=e_t@self.Wxh+h_prev@self.Whh+self.bias
      h_t=a_t
      hs[t]=h_t
      self.cache.append((idx, e_t, h_prev, a_t, h_t))
      h_prev=h_t
    return hs
  def backward(self, dinputs):
    self.dWxh  = np.zeros_like(self.Wxh)
    self.dWhh  = np.zeros_like(self.Whh)
    self.dbias = np.zeros_like(self.bias)
    dh_next    = np.zeros((1, self.Whh.shape[0]))

    for i in reversed(range(len(self.cache))):
        idx, e_t, h_prev, a_t, h_t = self.cache[i]

        dh = dinputs[i] + dh_next

        self.dWxh  += e_t.T    @ dh
        self.dWhh  += h_prev.T @ dh
        self.dbias += np.sum(dh, axis=0, keepdims=True)

        dh_next = dh @ self.Whh.T

    return self.dWxh, self.dWhh, self.dbias


class Output_Layer():
  def __init__(self,hidden_size,vocab_size):
    self.weights=np.random.randn(hidden_size,vocab_size)*0.01
    self.bias=np.zeros((1,vocab_size))
  def forward(self,hidden_state):
    self.inputs=hidden_state
    self.output=np.dot(self.inputs,self.weights)+self.bias
    return self.output
  def backward(self,dinputs):

    self.dweights = self.inputs.T @ dinputs
    self.dbias = np.sum(dinputs, axis=0, keepdims=True)
    do_dh=self.weights.T
    op = dinputs @ do_dh
    return op
class Tanh_Activation_Function():
  def forward(self,inputs):
    self.outputs=np.tanh(inputs)
    return self.outputs
  def backward(self,dinputs):
    tanh_z=self.outputs
    dtanh_dzt=(1-(tanh_z**2))
    op=dtanh_dzt*dinputs
    return op

class Softmax_Layer:
  def forward(self,inputs):
    shifted = inputs - np.max(inputs, axis=1, keepdims=True)
    exp_vals=np.exp(shifted)
    self.output=exp_vals/np.sum(exp_vals,keepdims=True,axis=1)
    return self.output
  def backward(self,dvalues):
    self.dinputs = np.empty_like(dvalues)
    for index, (single_output, single_dvalue) in enumerate(
            zip(self.output, dvalues)
        ):
      single_output = single_output.reshape(-1, 1)
      jacobian_matrix = (
                np.diagflat(single_output)
                - np.dot(single_output, single_output.T)
            )
      self.dinputs[index] = np.dot(jacobian_matrix, single_dvalue)
      return self.dinputs
class Categorical_Cross_Entropy:
  def forward(self,y_pred,y_true):
    clipped_val=np.clip(y_pred,1e-7, 1 - 1e-7)
    samples = len(y_pred)
    clipped_vals=np.clip(y_pred,1e-7, 1 - 1e-7)
    if len(y_true.shape)==1:
      correct_confidences=clipped_vals[range(samples),y_true]
    elif len(y_true.shape)==2:
      correct_confidences=np.sum(clipped_vals * y_true, axis=1)
    data_loss = -np.log(correct_confidences)
    output=np.mean(data_loss)
    return output
  def backward(self,y_pred,y_true):
    samples = len(y_pred)
    labels=len(y_pred[0])
    #np.eye(n) creates an identity matrix with diamenntios n*n
    if len(y_true.shape) == 1:
      y_true=np.eye(labels)[y_true]
      self.d_values=-y_true/y_pred
      self.d_values=self.d_values/samples
      return self.d_values

class SGD:
    def __init__(self, learning_rate=0.01):
        self.lr = learning_rate

    def update(self, layer):
        layer.weights -= self.lr * layer.dweights
        layer.biases -= self.lr * layer.dbiases

# %% [markdown]
# Forward Pass

# %%
hidden=Hidden_Layer(vocab_size=27,embed_size=10,hidden_size=100)
tanh=Tanh_Activation_Function()
output_layer=Output_Layer(hidden_size=100,vocab_size=27)
softmax=Softmax_Layer()
loss=Categorical_Cross_Entropy()
a=hidden.forward(X)
b=tanh.forward(a)
c=output_layer.forward(b)
d=softmax.forward(c)
e=loss.forward(d, np.array(Y))

# %%
e
# Out:
# np.float64(3.295839307427546)

# %%
print("d shape:", d.shape)
print("Y shape:", np.array(Y).shape)
# Out:
# d shape: (13, 27)
# Y shape: (13,)

# %%
print("X:", X)
print("Y:", Y)
# Out:
# X: [1, 1, 3, 8, 5, 14, 15, 19, 1, 21, 18, 21, 19]
# Y: [1, 3, 8, 5, 14, 15, 19, 1, 21, 18, 21, 19, 0]

# %%
d1 = loss.backward(d, np.array(Y))


d2 = softmax.backward(d1)


d3 = output_layer.backward(d2)


d4 = tanh.backward(d3)

dWxh, dWhh, dbias = hidden.backward(d4)

# %%
dWhh
# Out:
# array([[ 4.20678961e-06,  2.24339578e-06,  1.04517296e-06, ...,
#          1.29737689e-06, -6.62686045e-07,  7.61324300e-06],
#        [ 1.92973412e-06,  3.38330298e-06,  3.88967981e-06, ...,
#         -4.85288855e-07,  4.83071669e-06, -9.29251157e-06],
#        [-1.46188305e-06, -2.54295447e-06, -1.37557050e-06, ...,
#          1.47130892e-06, -2.29469011e-07, -7.85124629e-06],
#        ...,
#        [ 9.20560902e-06,  3.18690945e-06, -2.68612153e-06, ...,
#         -7.45216710e-06,  1.91544524e-06, -1.34166816e-05],
#        [-1.06740639e-05, -2.82381064e-06,  7.07852276e-07, ...,
#          8.12785618e-06,  1.39746172e-06, -4.55191672e-06],
#        [-2.43373587e-06,  1.99630260e-06,  3.76389596e-06, ...,
#          7.94615426e-06,  2.71702030e-06,  1.02746522e-05]])

# %%
dbias
# Out:
# array([[ 0.002058  , -0.02059333,  0.03372856,  0.08235105, -0.0182347 ,
#          0.03574907, -0.03479362,  0.02359908,  0.01997727, -0.02154433,
#          0.05161188, -0.01951216,  0.05090231,  0.00834288, -0.03080283,
#          0.02966063,  0.0487353 ,  0.0019432 ,  0.01666339, -0.08455025,
#          0.02443461,  0.03221165, -0.0340389 , -0.04645577,  0.04032613,
#         -0.0074253 ,  0.02315671, -0.0047236 ,  0.07992668, -0.04103991,
#          0.09770543,  0.01126299, -0.0140694 , -0.00779046, -0.01099362,
#          0.01628707,  0.05028953,  0.00524994,  0.00371432, -0.00577863,
#         -0.00059209,  0.0212409 ,  0.08841049, -0.03426777,  0.0273749 ,
#         -0.06636394, -0.04032724, -0.03241254,  0.01682913, -0.03495302,
#          0.0411518 ,  0.04761505, -0.0425915 , -0.03874513, -0.00702421,
#         -0.02285379,  0.04890036, -0.04507985, -0.0237124 , -0.05538919,
#          0.01965685,  0.00893203,  0.0543634 , -0.02730117, -0.00010499,
#         -0.07037499, -0.00104172,  0.04255647, -0.00294242, -0.05702548,
#          0.01036246, -0.00023929,  0.01694747,  0.01059978, -0.04021026,
#          0.02871962, -0.01807813, -0.01176475,  0.01358478,  0.06571597,
#          0.01543942, -0.02785229,  0.02883858, -0.03454913, -0.05881322,
#         -0.01239104, -0.02070187, -0.03312307, -0.02887831,  0.00408106,
#          0.00753373,  0.02579544,  0.03180032,  0.06704608, -0.00562362,
#         -0.01481028,  0.07239068,  0.05169833, -0.02880599, -0.04190119]])

# %%
dWxh
# Out:
# array([[ 4.28907968e-04, -9.00879451e-05, -1.96009396e-04,
#          2.73401061e-04,  1.45409948e-04,  7.60765157e-05,
#         -1.39997466e-04,  3.85206136e-04, -2.69657087e-04,
#          7.17392314e-05,  1.69418528e-04, -4.51744215e-04,
#          6.46986043e-04, -4.37037340e-04,  4.71600231e-04,
#          5.65686735e-04, -1.38501674e-04,  1.40042457e-04,
#         -2.61619866e-04, -4.38725566e-04,  2.37948896e-04,
#          4.82568452e-04, -4.42589191e-04,  1.76354727e-04,
#          2.38721145e-04,  5.98141299e-04,  3.11536179e-04,
#         -5.23123014e-05,  3.17607142e-04, -1.28208305e-04,
#         -3.53551162e-05, -2.99837880e-04, -5.58504705e-05,
#         -2.55820391e-05,  6.40697869e-05,  6.73109786e-05,
#          2.52966388e-04,  3.61993415e-04, -3.71309954e-04,
#         -3.63131181e-04, -2.27232149e-04,  3.66793425e-04,
#         -3.75156648e-04, -2.87553269e-04, -9.13023265e-05,
#          2.21034748e-06, -7.24710760e-05,  2.21152223e-04,
#          6.04295266e-04,  7.33746483e-04,  1.75741756e-04,
#          6.69526750e-04,  1.11091977e-04, -2.39912639e-04,
#         -3.32903325e-04],
#        [ 8.05355898e-05, -9.37923775e-05, -2.59508634e-04,
#         -5.84578376e-05,  1.58277343e-04, -1.09115901e-04,
#         -4.79985552e-04, -1.12349976e-04,  2.79622629e-04,
#          1.62858073e-04, -2.83827099e-04,  2.43503343e-04,
#         -1.18006730e-04,  3.77009959e-04, -7.01222822e-05,
#         -4.98401367e-05,  2.93079338e-04, -2.42553014e-05,
#         -3.11306700e-04, -3.35139140e-04, -4.38641358e-05,
#          2.77755407e-05,  3.75926423e-05, -1.32427789e-04,
#          3.75378335e-04, -3.11495943e-04, -1.40737197e-05,
#          1.56546701e-04,  5.31772401e-04, -3.12792523e-05,
#          2.37984990e-04, -1.29901503e-04,  1.71627708e-04,
#          7.81783251e-05, -1.64412250e-04, -3.27226146e-05,
#         -5.69679545e-04, -1.18894752e-04, -3.43875207e-04,
#         -8.50406131e-05, -1.53652487e-04,  2.32478162e-05,
#         -7.95423997e-05, -4.37562301e-05,  3.72528119e-04,
#          1.94630147e-04,  3.61210358e-04,  1.22537165e-04,
#         -1.81913294e-04,  3.83214112e-04,  1.66552155e-05,
#         -1.55555969e-04, -1.25234236e-04, -2.76827967e-04,
#         -3.17729834e-04,  1.80420421e-04,  4.25639045e-04,
#         -4.69607625e-04,  1.47360037e-04, -3.45474541e-05,
#          2.41503693e-04,  1.29915481e-04, -1.37689059e-04,
#          2.42613129e-04,  4.91011191e-05, -5.77118969e-04,
#          9.33819193e-05,  6.59647279e-05, -2.34103952e-04,
#         -1.19609944e-04, -6.82484374e-04, -2.02888274e-04,
#          1.35766561e-04, -3.87336705e-04,  7.36750393e-05,
#          2.28171560e-04, -1.84228377e-05, -4.68112797e-04,
#         -7.50051979e-05, -5.14845215e-04, -1.94199328e-04,
#         -1.39870038e-04, -2.84250876e-04,  2.98176389e-04,
#         -5.33529091e-04,  6.76316447e-04, -7.64612001e-05,
#         -3.27548166e-04, -2.94437254e-04, -3.34853162e-04,
#          1.19835381e-04, -4.63780339e-06,  7.33582936e-05,
#          2.44990398e-05, -1.29429377e-04, -5.59023058e-05,
#         -1.90272443e-04, -9.67750981e-05,  3.01058109e-05,
#         -1.29031763e-04]])

# %%
for epoch in range(100):
    # forward
    a = hidden.forward(X)
    b = tanh.forward(a)
    c = output_layer.forward(b)
    d = softmax.forward(c)
    e = loss.forward(d, np.array(Y))

    # backward
    d1 = loss.backward(d, np.array(Y))
    d2 = softmax.backward(d1)
    d3 = output_layer.backward(d2)
    d4 = tanh.backward(d3)
    dWxh, dWhh, dbias = hidden.backward(d4)

    # update weights
    output_layer.weights -= 0.01 * output_layer.dweights
    output_layer.bias    -= 0.01 * output_layer.dbias
    hidden.Wxh           -= 0.01 * dWxh
    hidden.Whh           -= 0.01 * dWhh
    hidden.bias          -= 0.01 * dbias

    if epoch % 10 == 0:
        print(f"Epoch {epoch} Loss: {e}")
# Out:
# Epoch 0 Loss: 3.295839307427546
# Epoch 10 Loss: 2.63265829235848
# Epoch 20 Loss: nan
# Epoch 30 Loss: nan
# Epoch 40 Loss: nan
# Epoch 50 Loss: nan
# Epoch 60 Loss: nan
# Epoch 70 Loss: nan
# Epoch 80 Loss: nan
# Epoch 90 Loss: nan
# /tmp/ipython-input-394/2324084264.py:113: RuntimeWarning: divide by zero encountered in divide
#   self.d_values=-y_true/y_pred
# /tmp/ipython-input-394/2324084264.py:113: RuntimeWarning: overflow encountered in divide
#   self.d_values=-y_true/y_pred
# /tmp/ipython-input-394/2324084264.py:113: RuntimeWarning: invalid value encountered in divide
#   self.d_values=-y_true/y_pred

# %%
import torch
import torch.nn as nn

# %%
class Vanilla_RNN(nn.Module):
  def __init__(self, vocab_size, embed_size, hidden_size):
    super(Vanilla_RNN,self).__init__()
    self.rnn=nn.RNN(embed_size,hidden_size,batch_first=True)
    self.embed=nn.Embedding(vocab_size,embed_size)
    self.output=nn.Linear(hidden_size, vocab_size)
  def forward(self,x,h0=None):
    e=self.embed(x)
    out,hn=self.rnn(e.unsqueeze(0), h0)
    logits=self.output(out.squeeze(0))
    return logits,hn

# %%
model     = Vanilla_RNN(vocab_size=27, embed_size=10, hidden_size=100)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
for epoch in range(100):
    optimizer.zero_grad()
    x      = torch.tensor(X)
    y      = torch.tensor(Y)
    logits, _ = model(x)
    loss   = criterion(logits, y)
    loss.backward()
    optimizer.step()
    if epoch % 10 == 0:
        print(f"Epoch {epoch} Loss: {loss.item()}")
# Out:
# Epoch 0 Loss: 3.324617862701416
# Epoch 10 Loss: 3.2332310676574707
# Epoch 20 Loss: 3.1427063941955566
# Epoch 30 Loss: 3.051687479019165
# Epoch 40 Loss: 2.958950996398926
# Epoch 50 Loss: 2.863403081893921
# Epoch 60 Loss: 2.764106273651123
# Epoch 70 Loss: 2.6603469848632812
# Epoch 80 Loss: 2.551752805709839
# Epoch 90 Loss: 2.4384586811065674

# %%
def predict(model, start_char, char_to_ix, ix_to_char, max_length=20):
    model.eval()

    # start with given character
    x = torch.tensor([char_to_ix[start_char]])
    h = None
    result = [start_char]

    with torch.no_grad():
        for _ in range(max_length):
            logits, h = model(x, h)


            probs = torch.softmax(logits[-1], dim=0)
            next_idx = torch.multinomial(probs, 1).item()
            next_char = ix_to_char[next_idx]


            if next_char == '\n':
                break

            result.append(next_char)
            x = torch.tensor([next_idx])

    return ''.join(result)


for _ in range(5):
    print(predict(model, 'a', char_to_ix, ix_to_char))
# Out:
# aqplwrpdrnrllpqggrceb
# azclaaemnirav
# advcqknv
# afemxbclxxqsurlrerpli
# a
